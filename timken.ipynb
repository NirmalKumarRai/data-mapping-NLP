# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import requests

# %%
titles = []
models = []

# %%
urls = pd.read_csv("Scrapestorm URLs.csv")

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import requests
urls = pd.read_csv("Scrapestorm URLs.csv")
titles = []
models = []
for url in urls['URLs']:
    r = requests.get(url)
    soup = BeautifulSoup(r.text,"lxml")
    title = soup.find("h1", class_ = "product-card__title").text
    titles.append(title)
    model = soup.find("p", class_ = "modelNo").text
    models.append(model)
    lis = soup.find("div", class_='m-accordion js-prod-accordion')
    spec_key = lis.find_all("p", class_ = "key")
    spec_value = lis.find_all("p", class_ = "value")
    key=[]
    for i in spec_key:
        x = i.text
        key.append(x)

    value=[]
    for i in spec_value:
        x = i.text
        value.append(x)

df = {"urls": url ,"tinken_title": titles, "tinken_model": models , "key": spec_key, "value": 'spec_value'}

# %%
url = "https://www.mrosupply.com/bearings/5066740_230500kymbw507c08c3_timken/"
# url = "https://www.mrosupply.com/bearings/5067917_saf-630_timken/"

# %%
r = requests.get(url)

# %%
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text,"lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken  - MROSupply.com
#   </title>
# <meta content="MROSupply.com" name="author"/>
# <meta content="The 230/500KYMBW507C08C3 is produced by Timken and is described as a TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken" name="description"/>
# <meta content="C65E148C7935B9F1A191E38C03A2B895" name="msvalidate.01"/>
# <meta content="width=device-width, height=device-height, initial-scale=1, user-scalable=0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="index" name="robots"/>
# <link as="font" crossorigin="anonymous" href="https://static.mrosupply.com/fonts/svgFont3.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://static.mrosupply.com/fontawesome/webfonts/fa-brands-400.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://static.mrosupply.com/fontawesome/webfonts/fa-solid-900.woff2" rel="preload" type="font/woff2"/>
# <link crossorigin="" href="https://static.mrosupply.com/" rel="preconnect"/>
# <link crossorigin="" href="https://bat.bing.com/" rel="preconnect"/>
# <link crossorigin="" href="https://polyfill.io/" rel="preconnect"/>
# <link crossorigin="" href="https://fast.a.klaviyo.com/" rel="preconnect"/>
# <link crossorigin="" href="https://static.klaviyo.com/" rel="preconnect"/>
# <link crossorigin="" href="https://static-forms.klaviyo.com/" rel="preconnect"/>
# <link crossorigin="" href="https://static-tracking.klaviyo.com/" rel="preconnect"/>
# <link crossorigin="" href="https://www.google-analytics.com/" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link crossorigin="" href="https://googleads.g.doubleclick.net/" rel="preconnect"/>
# <link href="https://static.mrosupply.com/css/2666d66fcdca.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
#       USER = {
#           loggedIn: false,
#           isStaff: false,
#           email: '',
#           IP: '125.63.118.134',
#           experiments: 'product_new_design_B,freeGiftMain,new_header,index_dashboard,homepageSlider,homepageBrands,uploadPictureB,blogs_index,sticky_cta,imageMagick,GA4,newProductCard,index-only_root_categories_C,specs_B,newPricingPortal,secondary_survey'
#       }
#     </script>
# <script crossorigin="anonymous" src="https://kit.fontawesome.com/6f8cece7f4.js"></script>
# <script type="text/javascript">
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-7504567-3', 'auto');
#         ga('require', 'GTM-PCKCFHS');
#         ga('require', 'ec');
#         ga('set', 'transport', 'beacon');
#       </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-MNNV0SMJQH"></script>
# <script>
#           window.dataLayer = window.dataLayer || [];
#           function gtag(){dataLayer.push(arguments);}
#           gtag('js', new Date());
#           gtag('config', 'G-MNNV0SMJQH');
#           gtag('config', 'AW-975205132');
#         </script>
# <link href="https://www.mrosupply.com/bearings/5066740_230500kymbw507c08c3_timken/" rel="canonical"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta name="twitter:domain" value="www.mrosupply.com"/>
# <meta name="twitter:title" value="TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken"/>
# <meta name="twitter:description" value="The 230/500KYMBW507C08C3 is produced by Timken and is described as a TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken"/>
# <meta name="twitter:url" value="https://www.mrosupply.com/bearings/5066740_230500kymbw507c08c3_timken/"/>
# <meta name="twitter:label1" value="Brand"/>
# <meta name="twitter:data1" value="Timken"/>
# <meta name="twitter:label2" value="Category"/>
# <meta name="twitter:data2" value="Tapered Bore Spherical Roller Bearings"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.mrosupply.com/bearings/5066740_230500kymbw507c08c3_timken/" property="og:url"/>
# <meta content="TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken" property="og:title"/>
# <meta content="The 230/500KYMBW507C08C3 is produced by Timken and is described as a TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken" property="og:description"/>
# <meta content="https://static.mrosupply.com/cache/2b/34/2b348ba1f7e73a2ca890c8b96242670d.jpg" property="og:image"/>
# <meta content="https://static.mrosupply.com/cache/2b/34/2b348ba1f7e73a2ca890c8b96242670d.jpg" name="twitter:image"/>
# </head>
# <body class="product-details">
# <div class="page-loader"><div class="page-loader--line" id="Loader"></div></div>
# <div class="layout-wrapper">
# <header class="o-header js-header-wrap">
# <div class="m-header-top m-header-top--sm">
# <div class="o-header-i">
# <a aria-label="Our contacts" class="a-link-btn js-contacts-handler" href="#">
# <span><i class="a-icon a-icon-email"></i>Contacts<i class="a-icon a-icon-arrow"></i></span>
# </a>
# <div class="m-header-top m-header-top-left">
# <div class="m-site-controls">
# <ul class="m-site-controls--list">
# <li class="m-site-controls--list-item">
# <a aria-label="If you have accessibility problems call (888) 671-2883" href="tel:8886712883" role="alert">
# <i class="a-icon a-icon-phone"></i>
# <b>USA</b>
# <span>+1 (888) 671-2883</span>
# </a>
# </li>
# <li class="m-site-controls--list-item">
# <a aria-label="If you have accessibility problems call +52 33 1930 9455" href="tel:+523319309455" role="alert">
# <i class="a-icon a-icon-phone"></i>
# <b>MX</b>
# <span>+52 (33) 1930-9455</span>
# </a>
# </li>
# <li class="m-site-controls--list-item">
# <a aria-label="Chat live" class="chat chat-open" href="#">
# <i class="a-icon a-icon-message-cloud"></i>
# <span>Chat Live</span>
# </a>
# </li>
# <li class="m-site-controls--list-item">
# <a aria-label="Email us" class="popup-page" href="/page/plain/contact-us/">
# <i class="a-icon a-icon-email"></i>
# <span>Email Us</span>
# </a>
# </li>
# <li class="m-site-controls--list-item">
# <a aria-label="FAQ" href="/page/faq/?utm_source=site&amp;utm_medium=topkink&amp;utm_campaign=FAQ_Page&amp;utm_content=Checkout_Online">
# <i class="a-icon a-icon-chat-clouds"></i>
# <span>FAQ</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-header-top m-header-top-right">
# <div class="m-site-controls">
# <ul class="m-site-controls--list">
# <li class="m-site-controls--list-item">
# <a href="/accounts/login/?next=/bearings/5066740_230500kymbw507c08c3_timken/" rel="nofollow">
# <i class="a-icon a-icon-ac-guy"></i>
# <span>Sign in</span>
# </a>
# </li>
# <li class="m-site-controls--list-item m-site-controls--list-item--join" rel="nofollow">
# <a href="/accounts/register/">
# <span>Register</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <script>
#       gtag('event', 'AB_Tests', {
#         'experiment_name': 'headerB'
#       });
# </script>
# <div class="m-header-middle m-header-middle--sm">
# <div class="o-header-i">
# <div class="u-flex">
# <div>
# <a class="a-link a-link--logo" href="/" title="MROSupply.com Home page">
# <img alt="" height="59" src="https://static.mrosupply.com/images/general/logo.svg" width="146"/>
# </a>
# <form action="/search_spring/" class="m-search-panel js-search-wrap">
# <div class="a-autocomplete-inner">
# <i class="a-icon a-icon-search"></i>
# <input autocomplete="off" class="a-input a-input--autocomplete js-search" data-url="/autocomplete/" name="q" placeholder="Enter part number or keyword" required=""/>
# <button class="a-btn a-btn-close js-autocomplete-close">
# <i class="a-icon a-icon-close"></i>
# </button>
# <button class="a-btn a-btn-blue js-autocomplete-search">
# <span>GO</span>
# </button>
# <div class="m-search-dropdown"><div class="m-search-dropdown-i js-autocomplete-dropdown"></div></div>
# </div>
# </form>
# </div>
# <div>
# <div class="m-featured-brands">
# <div class="m-featured-brands-item">
# <a href="/popular_products/sew-eurodrive/" title="SEW Eurodrive">
# <img alt="Nord Gearbox" class="u-hr" height="48" loading="lazy" src="https://static.mrosupply.com/images/header/brands/sew-eurodrive.png" width="48"/>
# </a>
# </div>
# <div class="m-featured-brands-item">
# <a href="/page/nord-quote-form/" title="Nord Gearbox">
# <img alt="Nord Gearbox" class="u-hr" height="48" loading="lazy" src="https://static.mrosupply.com/images/header/brands/nord.png" width="48"/>
# </a>
# </div>
# </div>
# <a aria-label="Open cart" class="m-small-cart js-mini-cart m-small-cart-empty" data-cart-id="None" data-free-ship="1" data-product-count="0" href="/cart/go_to/">
# <i class="a-icon a-icon-small-cart"></i>
# <span class="m-small-cart-icon-count js-cart-icon-count">0</span>
# <span class="m-small-cart-title">Cart</span>
# <span class="m-small-cart-text">
# <span class="m-small-cart-count js-cart-count">0</span> Items</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="m-header-bottom m-header-bottom--sm">
# <style>
#   @media only screen and (max-width: 767px)
#   div.o-cart-panel-i {
#   top: 135px;
#   }
#   </style>
# <div class="o-header-i">
# <nav class="m-site-nav" data-nav-bar="">
# <div class="m-site-nav-i">
# <div>
# <div class="m-categories-select">
# <btn aria-label="Product categories" class="a-btn a-btn-light js-categories-handler">
# <span>Categories</span>
# <i class="a-icon a-icon-arrow"></i>
# <i class="a-icon a-icon-close"></i>
# <i class="a-icon a-icon-burger"></i>
# </btn>
# </div>
# <a class="a-link a-link-dark m-site-nav--item" href="/">HOME</a>
# <a class="a-link a-link-dark m-site-nav--item" href="/page/about-us/">About Us</a>
# <a class="a-link a-link-dark m-site-nav--item" href="https://www.mrosupply.com/popular_products/conveyor-belts-new/">Conveyor Belts</a>
# <a class="a-link a-link-dark m-site-nav--item" href="/brands/">Brands</a>
# <a class="a-link a-link-dark m-site-nav--item" href="/popular_products/">Popular Products</a>
# <a class="a-link a-link-dark m-site-nav--item" href="/blog/">Blog</a>
# <a class="a-link a-link-dark m-site-nav--item" href="/page/contact-us/" rel="nofollow">Contact Us</a>
# </div>
# <div>
# <div class="header-print testActiveControl">
# <a href="javascript:window.print();">
# <i class="a-icon a-icon-print"></i>
# </a>
# </div>
# <a class="a-btn a-btn-blue a-btn-sm a-link a-link-dark m-site-nav--item" href="/accounts/submit_po/" rel="nofollow">PAY WITH PO</a>
# </div>
# </div>
# <div class="m-site-nav--btn"><a aria-label="More site navigation URLs" class="js-mobile-nav" href="#">...</a></div>
# <div class="m-site-nav--dropdown"></div>
# </nav>
# </div>
# </div>
# </header>
# <div class="content-layout">
# <div class="alert-wrapper">
# <div class="a-alert a-alert-error active">
# <a class="a-btn-close-alert js-close-alert" href="#" title="Close alert">
# <i class="a-icon a-icon-close"></i>
# </a>
# <p class="a-alert-info">We are not an authorized Timken distributor or in any way affiliated with Timken</p>
# </div>
# </div>
# </div>
# <div class="o-categories js-categories" data-categories-panel="">
# <div class="o-categories-title">
# <p>Categories</p>
# <a class="a-link js-categories-close" href="#" title="Close categories panel">
# <span class="a-icon a-icon-close"></span>
# </a>
# </div>
# <ul class="o-categories-list">
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="405" href="/abrasives/">
# <span>Abrasives</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="406" href="/adhesives-sealants-and-tape/">
# <span>Adhesives, Sealants and Tape</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="459" href="/automation/">
# <span>Automation</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="526" href="/bearings/">
# <span>Bearings</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="634" href="/belts/">
# <span>Belts</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="635" href="/bushings/">
# <span>Bushings</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="748" href="/chains-sprockets/">
# <span>Chains &amp; Sprockets</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="750" href="/cleaning/">
# <span>Cleaning</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="753" href="/clothing/">
# <span>Clothing</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="756" href="/clutches-and-brakes/">
# <span>Clutches and Brakes</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1019" href="/cutting-tools/">
# <span>Cutting Tools</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1122" href="/electric-motors/">
# <span>Electric Motors</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1021" href="/electrical/">
# <span>Electrical</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1123" href="/fasteners/">
# <span>Fasteners</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1175" href="/fleet-and-vehicle-maintenance/">
# <span>Fleet and Vehicle Maintenance</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1216" href="/furniture-and-food-service/">
# <span>Furniture and Food Service</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1252" href="/gears-gear-racks/">
# <span>Gears &amp; Gear Racks</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1477" href="/hvac/">
# <span>HVAC</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1371" href="/hand-tools/">
# <span>Hand Tools</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1372" href="/hardware/">
# <span>Hardware</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1493" href="/hydraulics-and-pneumatics/">
# <span>Hydraulics and Pneumatics</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1627" href="/lighting/">
# <span>Lighting</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1691" href="/linear-motion/">
# <span>Linear Motion</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1692" href="/lubrication/">
# <span>Lubrication</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1706" href="/machining/">
# <span>Machining</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1747" href="/material-handling/">
# <span>Material Handling</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="1997" href="/paint-painting-supplies/">
# <span>Paint &amp; Painting Supplies</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2218" href="/power-tools/">
# <span>Power Tools</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2236" href="/pumps/">
# <span>Pumps</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2300" href="/raw-materials/">
# <span>Raw Materials</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2407" href="/safety/">
# <span>Safety</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2452" href="/seals/">
# <span>Seals</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2454" href="/shaft-couplings-and-collars/">
# <span>Shaft Couplings and Collars</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2501" href="/sheaves/">
# <span>Sheaves</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2592" href="/speed-reducers/">
# <span>Speed Reducers</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2731" href="/synchronous-timing-belts/">
# <span>Synchronous &amp; Timing Belts</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2809" href="/tensioners-and-idlers/">
# <span>Tensioners and Idlers</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2810" href="/test-instruments/">
# <span>Test Instruments</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2811" href="/timing-belt-pulleys/">
# <span>Timing Belt Pulleys</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2972" href="/v-belts/">
# <span>V-Belts</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# <li class="o-categories-list--item">
# <a class="a-link" data-tree="2973" href="/welding/">
# <span>Welding</span>
# <i class="a-icon a-icon-arrow"></i>
# </a>
# </li>
# </ul>
# </div>
# <main>
# <div class="o-cart-panel js-cart-panel" data-cart-panel="" data-free="50">
# <div class="o-cart-panel-i js-cart-panel-i">
# <div class="a-cart-panel-close fa fa-solid fa-close js-cart-panel-close" title="Close cart panel"></div>
# <div class="o-cart-panel--overlay js-mcart-overlay">
# <i class="a-spinner">
# <svg class="a-spinner-i" viewbox="0 0 66 66" xmlns="http://www.w3.org/2000/svg">
# <circle class="sub-spinner" cx="33" cy="33" fill="none" r="30" stroke-linecap="round" stroke-width="6" style="opacity: 0.25; stroke: #ffffff"></circle>
# <circle class="path" cx="33" cy="33" fill="none" r="30" stroke-linecap="round" stroke-width="6"></circle>
# </svg>
# </i>
# </div>
# <div class="o-cart-panel--info-box">
# <div class="o-cart-panel--free">
# <div class="o-cart-panel--free-text js-free-text">
# </div>
# <div class="o-cart-panel--free-progress-i">
# <div class="o-cart-panel--free-progress js-mcart-free-progress"></div>
# </div>
# </div>
# <div class="o-cart-panel--empty">
# <i class="a-icon a-icon-small-cart"></i>
# <br/>
# <div class="o-cart-panel--empty-text">
#                   Add products to your shopping cart
#                 </div>
# </div>
# <div class="m-cart-product-list js-cart-panel-list"></div>
# <div class="m-cart-product-checkout js-checkout" style="display: none;">
# <div class="m-cart-product-checkout--total">
# <span class="a-checkout-title">Subtotal</span>
# <span class="a-checkout-price js-mcart-summ"></span>
# </div>
# <div class="m-cart-product-checkout-btns">
# <a class="a-btn a-btn-blue" href="/cart/go_to/">
# <span>Checkout now</span>
# </a>
# <a class="a-btn a-btn-blueHoverBtnBg" href="/cart/convert_to_quote/">
# <span>Get quote</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="content-layout">
# <div class="content-layout-i js-slide-layout">
# <script>
#       gtag('event', 'AB_Tests', {
#         'experiment_name': 'stickyCTA'
#       });
# </script>
# <div class="o-product-details">
# <div class="m-breadcrumbs" data-breadcrumbs="">
# <ul class="m-breadcrumbs-list" itemprop="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <li class="m-breadcrumbs-list--item">
# <a aria-label="Go to home page" class="a-link" href="/">Home</a>
# <i class="a-icon a-icon-arrow"></i>
# </li>
# <li class="m-breadcrumbs-list--item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a aria-label="Go to Bearings" class="a-link" href="/bearings/" itemprop="item">
# <span itemprop="name">Bearings</span>
# </a>
# <meta content="1" itemprop="position"/>
# <i class="a-icon a-icon-arrow"></i>
# </li>
# <li class="m-breadcrumbs-list--item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a aria-label="Go to Roller Bearings" class="a-link" href="/bearings/roller-bearings/" itemprop="item">
# <span itemprop="name">Roller Bearings</span>
# </a>
# <meta content="2" itemprop="position"/>
# <i class="a-icon a-icon-arrow"></i>
# </li>
# <li class="m-breadcrumbs-list--item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a aria-label="Go to Spherical Roller Bearings" class="a-link" href="/bearings/roller-bearings/spherical-roller-bearings/" itemprop="item">
# <span itemprop="name">Spherical Roller Bearings</span>
# </a>
# <meta content="3" itemprop="position"/>
# <i class="a-icon a-icon-arrow"></i>
# </li>
# <li class="m-breadcrumbs-list--item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a aria-label="Go to Tapered Bore Spherical Roller Bearings" class="a-link" href="/bearings/roller-bearings/spherical-roller-bearings/tapered-bore-spherical-roller-bearings/" itemprop="item">
# <span itemprop="name">Tapered Bore Spherical Roller Bearings</span>
# </a>
# <meta content="4" itemprop="position"/>
# </li>
# </ul>
# </div>
# <div class="freeGift--banner">
# <a aria-label="Click to find out more about our free gifts on orders over $500" href="/page/free-gifts-on-orders-over-500/" title="Free Gifts on Orders Over $500 - Find out more">
# <img alt="Free Gifts on Orders Over $500 - Find out more" src="https://documents.mrosupply.com/file_uploads/banner.jpg"/>
# </a>
# </div>
# <script>
#       gtag('event', 'AB_Tests', {
#         'experiment_name': 'PDPB'
#       });
# </script>
# <div class="productDetail js-catalogue-product js-product-availability" data-product-pk="5066740" data-refresh="False">
# <div class="productDetail--card">
# <div class="productDetail--card--content">
# <div class="productDetail--row">
# <div class="productDetail--image">
# <img alt="230/500KYMBW507C08C3" onerror="this.onerror=null; this.src='https://static.mrosupply.com/images/noimage.webp';" src="https://static.mrosupply.com/cache/2b/34/2b348ba1f7e73a2ca890c8b96242670d.jpg" width="205"/>
# <p class="muted"><em>
#             Image for Illustration purposes only. Actual product may vary
#           </em></p>
# </div>
# <div class="productDetail--info">
# <h1 class="product-card__title">TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken</h1>
# <p class="modelNo"><strong>MODEL</strong> 230/500KYMBW507C08C3</p>
# <div class="flex-table">
# <div class="flex-table--item">
# <div class="flex-table--head">
# <p>BRAND</p>
# </div>
# <div class="flex-table--body">
# <p><a aria-label="View all products from brand Timken" class="js-brand-name" href="/brands/timken/">Timken</a></p>
# </div>
# </div>
# <div class="flex-table--item">
# <div class="flex-table--head">
# <p>SKU</p>
# </div>
# <div class="flex-table--body">
# <p>5066740</p>
# </div>
# </div>
# <div class="flex-table--item">
# <div class="flex-table--head">
# <p>WEIGHT</p>
# </div>
# <div class="flex-table--body">
# <p>487.004 lb</p>
# </div>
# </div>
# <div class="flex-table--item">
# <div class="flex-table--head">
# <p title="UNIT OF MEASURE">UOM</p>
# </div>
# <div class="flex-table--body">
# <p>each</p>
# </div>
# </div>
# </div>
# <div class="productDetail--availability js-short-avail">
# </div>
# </div>
# </div>
# </div>
# <div class="productDetail--card--pricing">
# <div>
# <p class="price">Call for Pricing - 888-671-2883</p>
# <p class="muted reset">Typically Ships in: <span class="reset">1 day</span></p>
# </div>
# <div>
# <p class="u-margin-bottom">
# <span class="muted">Returnable:</span>
#         Yes
#         </p>
# </div>
# <div class="bookmark">
# <p><strong>Still Deciding?</strong></p>
# <p class="muted">
#           Add this item to your saved items and easily come back later.
#         </p>
# <i aria-label="Save this item" class="a-icon a-icon-bookmark js-favourite-product"></i>
# </div>
# </div>
# </div>
# </div>
# <div class="m-accordion js-prod-accordion">
# <div class="m-accordion--item">
# <div class="m-accordion--item--head">
# <p>SPECIFICATION</p>
# <img class="chevron" src="https://static.mrosupply.com/images/products/chevron-down.png"/>
# </div>
# <div class="m-accordion--item--body">
# <script>
#       gtag('event', 'AB_Tests', {
#         'experiment_name': 'Specifications_B'
#       });
#       </script>
# <div class="o-grid-table">
# <div class="o-grid-item">
# <p class="key">I.D.</p>
# <p class="value">19.6850 in</p>
# </div>
# <div class="o-grid-item">
# <p class="key">O.D.</p>
# <p class="value">28.3470 in</p>
# </div>
# </div>
# <div class="o-grid-table">
# <div class="o-grid-item">
# <p class="key">Outer ring backing diameter</p>
# <p class="value">26.500 in</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Static radial rating</p>
# <p class="value">1840000 lbf</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Inner ring "to clear" radius</p>
# <p class="value">0.200 in</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Design unit</p>
# <p class="value">METRIC</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Outer ring "to clear" radius</p>
# <p class="value">0.200 in</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Bore taper</p>
# <p class="value">1/12</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Dynamic radial rating (two-rows)</p>
# <p class="value">965000 lbf</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Inner ring width</p>
# <p class="value">6.575 in</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Cage material</p>
# <p class="value">BRASS</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Inner ring backing diameter</p>
# <p class="value">21.700 in</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Cage type</p>
# <p class="value">YMB</p>
# </div>
# <div class="o-grid-item">
# <p class="key">ISO factor</p>
# <p class="value">4.85</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Reference thermal speed rating (grease)</p>
# <p class="value">510</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Outer ring width</p>
# <p class="value">6.5750 in</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Geometry factor</p>
# <p class="value">0.1037</p>
# </div>
# <div class="o-grid-item">
# <p class="key">Reference thermal speed rating (oil)</p>
# <p class="value">580</p>
# </div>
# </div>
# </div>
# </div>
# <div class="m-accordion--item">
# <div class="m-accordion--item--head">
# <p>REVIEWS</p>
# <img class="chevron" src="https://static.mrosupply.com/images/products/chevron-down.png"/>
# </div>
# <div class="m-accordion--item--body js-product-review">
# <div class="o-product-review--item">
# <div class="o-product-review--stars star-5">
# <i class="a-icon a-icon-star"></i>
# <i class="a-icon a-icon-star"></i>
# <i class="a-icon a-icon-star"></i>
# <i class="a-icon a-icon-star"></i>
# <i class="a-icon a-icon-star"></i>
# </div>
# <p>SKU: 5066946</p>
# <p data-crop="" data-height="20">
# <span class="review-title">
#       Best company to buy from
#     </span>
# </p>
# <p data-crop="" data-height="50">
# <span class="review-text">
#       I always buy from MRO is a very reliable company to work with
#     </span>
# </p>
# <a class="js-product-review-popup">Read more</a>
# </div>
# </div>
# </div>
# <div class="m-accordion--item">
# <div class="m-accordion--item--head">
# <p>FAQs</p>
# <img class="chevron" src="https://static.mrosupply.com/images/products/chevron-down.png"/>
# </div>
# <div class="m-accordion--item--body">
# <div class="faq-item">
# <p class="faq-item--title">
# <a class="a-link a-link-blue" href="/page/faq/#answer_4_1" target="_blank">
#           When will I be charged for my order?</a>
# </p>
# </div>
# <div class="faq-item">
# <p class="faq-item--title">
# <a class="a-link a-link-blue" href="/page/faq/#answer_4_3" target="_blank">
#           Do you provide credit terms?</a>
# </p>
# </div>
# <div class="faq-item">
# <p class="faq-item--title">
# <a class="a-link a-link-blue" href="/page/faq/#answer_4_5" target="_blank">
#           Can I get a discounted price? I am a reseller / government entity.</a>
# </p>
# </div>
# <div class="faq-item">
# <p class="faq-item--title">
# <a class="a-link a-link-blue" href="/page/faq/#answer_5_1" target="_blank">
#           What is the return/warranty policy?</a>
# </p>
# </div>
# <div class="faq-item">
# <p class="faq-item--title">
# <a class="a-link a-link-blue" href="/page/faq/#answer_3_5" target="_blank">
#           Can it be shipped today?</a>
# </p>
# </div>
# <div class="faq-item">
# <p class="faq-item--title">
# <a class="a-link a-link-blue" href="/page/faq/#answer_3_7" target="_blank">
#           Does “Usually ships in 24 hours” mean it’s in stock?</a>
# </p>
# </div>
# <div class="faq-item">
# <p class="faq-item--body">
# <a class="a-link a-link-blue" href="/page/faq/" target="_blank">
#           Read full FAQ</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="m-accordion--item" id="freeGiftSection">
# <div class="m-accordion--item--head">
# <p><img class="gifter" src="https://static.mrosupply.com/images/products/gift.gif"/>FREE GIFTS ON ORDERS OVER $500</p>
# </div>
# <div class="m-accordion--item--body--alt">
# <div>
# <p>When you get to checkout, you’ll be able to select a free gift! Depending on the cart value, you’ll be shown relevant gifts your order qualifies for. </p>
# <div class="sm-grid">
# <div class="sm-grid--row">
# <div>
# <p class="sm-grid--title">$500</p>
# <p class="sm-grid-body">
#                     MRO Hat<br/>
#                     MRO Golf Balls<br/>
#                     MRO Hi-Vis Vests<br/>
#                     MRO Mug
#                   </p>
# </div>
# <div>
# <p class="sm-grid--title">$750</p>
# <p class="sm-grid-body">
#                     32oz Water Bottle<br/>
#                     Throw Blanket<br/>
#                     30 piece Hex Set<br/>
#                     Telescopic Pick Up
#                   </p>
# </div>
# <div>
# <p class="sm-grid--title">$1,250</p>
# <p class="sm-grid-body">
#                     Golf Cooler<br/>
#                     11-in-1 Screw Driver Set<br/>
#                     Gorilla Grip Knee Pad<br/>
#                     John Deere Oilskin Hat
#                   </p>
# </div>
# </div>
# <div class="sm-grid--row">
# <div>
# <p class="sm-grid--title">$2,500</p>
# <p class="sm-grid-body">
#                     Igloo 1/2 Gallon Jug<br/>
#                     Rechargable Headlamp<br/>
#                     Larix Trucker Hat
#                   </p>
# </div>
# <div>
# <p class="sm-grid--title">$5,000</p>
# <p class="sm-grid-body">
#                     Igloo 10 Gallon Cooler<br/>
#                     Igloo Party Bucket Cooler<br/>
#                     Klein Tools Speaker<br/>
#                     Klein Tools 8-in-1
#                   </p>
# </div>
# <div>
# <p class="sm-grid--title">$7,500</p>
# <p class="sm-grid-body">
#                     GX-6F Pro Golf Range Finder<br/>
#                     Bushnell Outdoorsman Speaker<br/>
#                     Jaeger 24px Ratcheting Wrench Set<br/>
#                     Aspen Beverage Bucket
#                   </p>
# </div>
# </div>
# </div>
# </div>
# <div>
# <img src="https://documents.mrosupply.com/file_uploads/freegifts_1.png"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <div class="o-overlay js-overlay"></div>
# <div class="o-footer-buffer js-footer-buffer"></div>
# </div>
# <footer class="o-footer js-footer">
# <div class="m-pays-secure">
# <div class="m-pays-secure-i">
# <div class="m-pays-secure--list m-pays-secure--list-pays">
# <div class="m-pays-secure--list-title">
# <span>We Accept:</span>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-visa"></i>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-master-card"></i>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-discover"></i>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-american-express"></i>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-paypal"></i>
# </div>
# </div>
# <div class="m-pays-secure--list m-pays-secure--list-secure">
# <div class="m-pays-secure--list-title">
# <span>Secure &amp; Private:</span>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-ver_paypal"></i>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-ver_visa"></i>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-truste"></i>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-verified"></i>
# </div>
# <div class="m-pays-secure--list-item">
# <i class="a-icon a-icon-norton"></i>
# </div>
# </div>
# </div>
# </div>
# <div class="m-footer-nav">
# <div class="m-footer-nav--list">
# <div class="m-footer-nav--list-item">
# <p class="m-footer-nav--list-item-title"><strong>CUSTOMER SERVICE</strong></p>
# <ul>
# <li>
# <a href="tel:8886712883">Call: (888)-671-2883 *</a>
# </li>
# <li>
# <a class="chat-open" href="#" rel="nofollow">Chat with sales</a>
# </li>
# <li>
# <a href="/page/contact-us/" rel="nofollow">Contact us</a>
# </li>
# <li>
# <a href="/page/faq/?utm_source=site&amp;utm_medium=footer&amp;utm_campaign=FAQ_Page&amp;utm_content=Checkout_Online" rel="nofollow">FAQ</a>
# </li>
# </ul>
# <div class="m-footer-nav--list-item-info">
#         * Service available from MON to FRI, from 5:00AM to 4:00PM P.S.T
#       </div>
# </div>
# <div class="m-footer-nav--list-item">
# <p class="m-footer-nav--list-item-title">Useful Links</p>
# <ul>
# <li>
# <a href="https://www.mrosupply.com/page/terms-of-purchase/" target="_blank">Terms of Purchase</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/page/freight-delivery-policy/">Delivery Policy</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/cindex/">Sitemap</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/page/mrosupply-coupon-codes/">MROSupply Coupon Codes</a>
# </li>
# </ul>
# </div>
# <div class="m-footer-nav--list-item">
# <p class="m-footer-nav--list-item-title">Suggested products</p>
# <ul>
# <li>
# <a href="https://www.mrosupply.com/popular_products/dixon-sanitary/">Dixon Sanitary</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/popular_products/allen-bradley/">Allen Bradley</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/popular_products/ax-v-belts/">AX Section V-Belts</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/popular_products/nexen-catalog-friction-brakes/">Nexen Catalog</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/brands/bell-gossett/">Bell &amp; Gossett</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/page/obsolete-products-pages/">Obsolete Products</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/blog/allen-bradley-push-buttons-applications/">Allen Bradley 800f</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/page/genuine-stearns-brake-replacement-parts/">Stearns Brake Replacement Parts</a>
# </li>
# <li>
# <a href="https://www.mrosupply.com/popular_products/Set-Screw-Pillow-Blocks-Standard-Duty/">Set screw pillow blocks</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-footer-contacts">
# <div class="m-footer-contacts-i">
# <div class="m-footer-contacts--copyright">
# <span>Company owned &amp; operated in the U.S.</span>
# <span>MRO Supply, Inc. 2915 E Washington Blvd. Los Angeles,CA. 90023 © 2023 MRO Supply, Inc. All rights reserved.</span>
# </div>
# <div class="m-footer-contacts--join-us">
# <span>Join Us</span>
# <a href="https://www.facebook.com/pages/MROSupply/298927910189281" title="Join Us on FaceBook">
# <i class="a-icon a-icon-fb"></i>
# </a>
# <a href="https://www.youtube.com/channel/UCgChm1LYQB0_vXyApJNMJYA" title="Join Us on YouTube">
# <i class="a-icon a-icon-yt"></i>
# </a>
# </div>
# </div>
# </div>
# <script src="https://polyfill.io/v3/polyfill.js" type="text/javascript"></script>
# <script src="https://static.mrosupply.com/js/f30491295225.js" type="text/javascript"></script>
# <script src="https://static.mrosupply.com/js/0cd9e066dd0f.js" type="text/javascript"></script>
# <link href="https://static.mrosupply.com/css/print.css" media="print" rel="stylesheet" type="text/css"/>
# <noscript>
# <img alt="" height="1" src="https://px.ads.linkedin.com/collect/?pid=2059932&amp;fmt=gif" style="display:none;" width="1"/>
# </noscript>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/975205132/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <div id="livechat-button-8ecffdb7-1c7a-4513-8ac9-24bed7d7f1a3"></div>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org/",
#     "@type": "Product",
#     "category": "Bearings, Roller Bearings, Spherical Roller Bearings, Tapered Bore Spherical Roller Bearings",
#     "name": "TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken",
#     "description": "The 230/500KYMBW507C08C3 is produced by Timken and is described as a TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken",
#
#     "brand": {
#         "@type": "Brand",
#         "name": "Timken",
#         "url": "/brands/timken/"
#     },
#
#     "mpn": "230/500KYMBW507C08C3",
#     "sku": "5066740",
#     "weight": "487.004 lb",
#
#
#     "image": "https://static.mrosupply.com/cache/2b/34/2b348ba1f7e73a2ca890c8b96242670d.jpg",
#
#     "offers": [
#
# {
#     "@type": "Offer",
#     "seller": {
#         "@type": "Organization",
#         "name": "MROSupply.com"
#     },
#     "url": "https://www.mrosupply.com/bearings/5066740_230500kymbw507c08c3_timken/",
#     "priceCurrency": "USD",
#     "availability": "http://schema.org/OutOfStock",
#     "price": "0",
#
#     "itemCondition": "http://schema.org/NewCondition"
# }
#
#     ]
#
#   }
# </script>
# <script type="text/javascript">
# window.PRODUCT = {
#   ga_attributes: {}
# };
# </script>
# </div></footer></body>
# </html>

# %%
title = soup.find("h1", class_ = "product-card__title").text
titles.append(title)
print(titles)
# Out:
# ['TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken', 'TIMKEN SAF 630 SRB Pillow Block Housing Only', 'TIMKEN 230/500KYMBW507C08C3 SRB 600-900mm OD Timken']

# %%
breadcrumbs = [item.get_text(strip=True) for item in soup.select('.m-breadcrumbs-list--item [itemprop="name"]')]
print(breadcrumbs)
# Out:
# ['Bearings', 'Roller Bearings', 'Spherical Roller Bearings', 'Tapered Bore Spherical Roller Bearings']

# %%
br = soup.find("li", class_="m-breadcrumbs-list--item")
bread = br.find("a", class_="a-link")['href'] 
print(bread)
# Out:
# /

# %%
lis = soup.find("div", class_='m-accordion js-prod-accordion')
spec_key = lis.find_all("p", class_ = "key")
spec_value = lis.find_all("p", class_ = "value")
key=[]
for i in spec_key:
    x = i.text
    key.append(x)

print(key)
value=[]
for i in spec_value:
    x = i.text
    value.append(x)

print(value)
# Out:
# []
# []

# %%
df = {"urls": url ,"tinken_title": titles, "tinken_model": models , "key": spec_key, "value": 'spec_value'}

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

urls = pd.read_csv("Scrapestorm URLs.csv")
data = []

for url in urls['URLs'].iloc[0:10]:
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    
    title = soup.find("h1", class_="product-card__title").text
    model = soup.find("p", class_="modelNo").text
    
    lis = soup.find("div", class_='m-accordion js-prod-accordion')
    if lis:
        spec_key = [i.text for i in lis.find_all("p", class_="key")]
        spec_value = [i.text for i in lis.find_all("p", class_="value")]
    else:
        spec_key = []
        spec_value = []

    data.append({
        "urls": url,
        "tinken_title": title,
        "tinken_model": model,
        "key": spec_key,
        "value": spec_value
    })

df = pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\raptor supplies\22nov\timken.ipynb Cell 14 line 1
#       <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> r = requests.get(url)
#      <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> soup = BeautifulSoup(r.text, "lxml")
# ---> <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> title = soup.find("h1", class_="product-card__title").text
#      <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a> model = soup.find("p", class_="modelNo").text
#      <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a> lis = soup.find("div", class_='m-accordion js-prod-accordion')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

urls = pd.read_csv("Scrapestorm URLs.csv")
data = []

for url in urls['URLs']:
    r = requests.get(url)
    if r.text == 200:
        soup = BeautifulSoup(r.text, "lxml")
        
        # Find title
        title_element = soup.find("h1", class_="product-card__title")
        title = title_element.text if title_element else None
        
        # Find model
        model_element = soup.find("p", class_="modelNo")
        model = model_element.text if model_element else None

        #find breadcrumb
        breadcrumbs = [item.get_text(strip=True) for item in soup.select('.m-breadcrumbs-list--item [itemprop="name"]')]
        
        # Find specifications
        lis = soup.find("div", class_='m-accordion js-prod-accordion')
        if lis:
            spec_key = [i.text for i in lis.find_all("p", class_="key")]
            spec_value = [i.text for i in lis.find_all("p", class_="value")]
        else:
            spec_key = []
            spec_value = []

        data.append({
            "urls": url,
            "tinken_title": title,
            "tinken_model": model,
            "key": spec_key,
            "value": spec_value,
            "breadcrumb" : breadcrumbs
        })

    df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\raptor supplies\22nov\timken.ipynb Cell 16 line 9
#       <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> data = []
#       <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> for url in urls['URLs']:
# ----> <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a>     r = requests.get(url)
#      <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a>     if r.text == 200:
#      <a href='vscode-notebook-cell:/d%3A/raptor%20supplies/22nov/timken.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a>         soup = BeautifulSoup(r.text, "lxml")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#     360     tls_in_tls = False
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %%
df
# Out:
#                                                   urls  \
# 0    https://www.mrosupply.com/bearings/5067028_140...
# 1    https://www.mrosupply.com/bearings/5119833_170...
# 2    https://www.mrosupply.com/bearings/5078787_180...
# 3    https://www.mrosupply.com/bearings/5073024_190...
# 4    https://www.mrosupply.com/bearings/5119433_195...
# ..                                                 ...
# 477  https://www.mrosupply.com/bearings/5100429_snt...
# 478  https://www.mrosupply.com/bearings/5100430_snt...
# 479  https://www.mrosupply.com/bearings/5100431_snt...
# 480  https://www.mrosupply.com/bearings/5119627_snt...
# 481  https://www.mrosupply.com/bearings/5100404_snt...
#
#                                           tinken_title  \
# 0             TIMKEN 140TP158DO 070 CRB Thrust < 24 OD
# 1    TIMKEN 170RIU664 R3 CRB 24-36 OD Timken Single...
# 2        TIMKEN 180RIN683 R2 CRB >36 Timken Single Row
# 3     TIMKEN 190RU03 R3 CRB 12-24 OD Timken Single Row
# 4    TIMKEN 195TTSV938 OA452 TRB Thrust Machine Rac...
# ..                                                 ...
# 477                                               None
# 478                                               None
# 479     TIMKEN SNT 3160 SRB Plummer Block Housing Only
# 480                                               None
# 481                                               None
#
#                tinken_model key value
# 0      MODEL 140TP158DO 070  []    []
# 1        MODEL 170RIU664 R3  []    []
# 2        MODEL 180RIN683 R2  []    []
# 3          MODEL 190RU03 R3  []    []
# 4    MODEL 195TTSV938 OA452  []    []
# ..                      ...  ..   ...
# 477                    None  []    []
# 478                    None  []    []
# 479          MODEL SNT 3160  []    []
# 480                    None  []    []
# 481                    None  []    []
#
# [482 rows x 5 columns]

# %%
df.to_csv('timken.csv')

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

urls = pd.read_csv("Scrapestorm URLs.csv")
data = []

for url in urls['URLs']:
    r = requests.get(url)
    if r.status_code == 200:
        soup = BeautifulSoup(r.text, "lxml")
        
        # Find title
        title_element = soup.find("h1", class_="product-card__title")
        title = title_element.text if title_element else None
        
        # Find model
        model_element = soup.find("p", class_="modelNo")
        model = model_element.text if model_element else None

        # Find breadcrumb
        br = soup.find("li", class_="m-breadcrumbs-list--item")
        bread = br.find("a", class_="a-link").get('href') if br else None
        
        # Find specifications
        lis = soup.find("div", class_='m-accordion js-prod-accordion')
        if lis:
            spec_key = [i.text for i in lis.find_all("p", class_="key")]
            spec_value = [i.text for i in lis.find_all("p", class_="value")]
        else:
            spec_key = []
            spec_value = []

        data.append({
            "urls": url,
            "tinken_title": title,
            "tinken_model": model,
            "key": spec_key,
            "value": spec_value,
            "breadcrumb": bread
        })

df = pd.DataFrame(data)
print(df)
# Out:
#                                                   urls  \
# 0    https://www.mrosupply.com/bearings/5067028_140...
# 1    https://www.mrosupply.com/bearings/5119833_170...
# 2    https://www.mrosupply.com/bearings/5078787_180...
# 3    https://www.mrosupply.com/bearings/5073024_190...
# 4    https://www.mrosupply.com/bearings/5119433_195...
# ..                                                 ...
# 204  https://www.mrosupply.com/bearings/5100247_sda...
# 205  https://www.mrosupply.com/bearings/5079209_sda...
# 206  https://www.mrosupply.com/bearings/5100420_snt...
# 207  https://www.mrosupply.com/bearings/5100429_snt...
# 208  https://www.mrosupply.com/bearings/5119627_snt...
#
#                                           tinken_title  \
# 0             TIMKEN 140TP158DO 070 CRB Thrust < 24 OD
# 1    TIMKEN 170RIU664 R3 CRB 24-36 OD Timken Single...
# 2        TIMKEN 180RIN683 R2 CRB >36 Timken Single Row
# 3     TIMKEN 190RU03 R3 CRB 12-24 OD Timken Single Row
# 4    TIMKEN 195TTSV938 OA452 TRB Thrust Machine Rac...
# ..                                                 ...
# 204  TIMKEN SDAF3180KX14 15/16 SRB Pillow Block Hou...
# 205  TIMKEN SDAFS 22526L FXCL SRB Pillow Block Asse...
# 206     TIMKEN SNT 3036 SRB Plummer Block Housing Only
# 207     TIMKEN SNT 3152 SRB Plummer Block Housing Only
# 208    TIMKEN SNT 3172L SRB Plummer Block Housing Only
#
#                  tinken_model key value breadcrumb
# 0        MODEL 140TP158DO 070  []    []          /
# 1          MODEL 170RIU664 R3  []    []          /
# 2          MODEL 180RIN683 R2  []    []          /
# 3            MODEL 190RU03 R3  []    []          /
# 4      MODEL 195TTSV938 OA452  []    []          /
# ..                        ...  ..   ...        ...
# 204  MODEL SDAF3180KX14 15/16  []    []          /
# 205   MODEL SDAFS 22526L FXCL  []    []          /
# 206            MODEL SNT 3036  []    []          /
# 207            MODEL SNT 3152  []    []          /
# 208           MODEL SNT 3172L  []    []          /
#
# [209 rows x 6 columns]

# %%
df.to_csv('timken.csv')

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
import random

urls = pd.read_csv("Scrapestorm URLs.csv")
data = []

for url in urls['URLs']:
    r = requests.get(url)
    status_code = r.status_code  # Store the status code
    if status_code == 200:
        soup = BeautifulSoup(r.text, "lxml")
        
        # Find title
        title_element = soup.find("h1", class_="product-card__title")
        title = title_element.text if title_element else None
        
        # Find model
        model_element = soup.find("p", class_="modelNo")
        model = model_element.text if model_element else None

        # Find breadcrumb
        breadcrumbs = [item.get_text(strip=True) for item in soup.select('.m-breadcrumbs-list--item [itemprop="name"]')]
        
        # Find specifications
        lis = soup.find("div", class_='m-accordion js-prod-accordion')
        if lis:
            spec_key = [i.text for i in lis.find_all("p", class_="key")]
            spec_value = [i.text for i in lis.find_all("p", class_="value")]
        else:
            spec_key = []
            spec_value = []

        data.append({
            "urls": url,
            "status_code": status_code,
            "tinken_title": title,
            "tinken_model": model,
            "key": spec_key,
            "value": spec_value,
            "breadcrumb": breadcrumbs
        })

        # Introduced a random delay between 2 and 5 seconds
        time.sleep(random.uniform(2, 5))

df2 = pd.DataFrame(data)
df2.to_csv("timken_scrap.csv")

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
import random

urls = pd.read_csv("mroscrapwork.csv")
url_list = []
status_code_list = []
title_list = []
model_list = []
spec_key_list = []
spec_value_list = []
breadcrumb_list = []


for url in urls['URLs']:
    r = requests.get(url)
    status_code = r.status_code  # Store the status code
    if status_code == 200:
        soup = BeautifulSoup(r.text, "lxml")
        
        # Find title
        title_element = soup.find("h1", class_="product-card__title")
        title = title_element.text if title_element else None
        title_list.append(title)

        # Find model
        model_element = soup.find("p", class_="modelNo")
        model = model_element.text if model_element else None
        model_list.append(model)

        # Find breadcrumb
        breadcrumbs = [item.get_text(strip=True) for item in soup.select('.m-breadcrumbs-list--item [itemprop="name"]')]
        breadcrumb_list.append(breadcrumbs)

        

        # Find specifications
        lis = soup.find("div", class_='m-accordion js-prod-accordion')
        if lis:
            spec_key = [i.text for i in lis.find_all("p", class_="key")]
            spec_value = [i.text for i in lis.find_all("p", class_="value")]
        else:
            spec_key = []
            spec_value = []

        spec_key_list.append(spec_key)
        spec_value_list.append(spec_value)
        url_list.append(url)
        status_code_list.append(status_code)

        # Introduced a random delay between 2 and 5 seconds
        time.sleep(random.uniform(2, 5))

# Create DataFrame after the loop
df2 = pd.DataFrame({
    "urls": url_list,
    "status_code": status_code_list,
    "tinken_title": title_list,
    "tinken_model": model_list,
    "key": spec_key_list,
    "value": spec_value_list,
    "breadcrumb": breadcrumb_list,

})

df2.to_csv("timken_scrap.csv")
